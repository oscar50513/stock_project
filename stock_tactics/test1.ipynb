# %%
import os
import pandas as pd
import pandas as pd
import numpy as np
from datetime import datetime
from talib import abstract

dir = os.getcwd()+"\stocks"
files = os.listdir(dir)
print(files)
for file in files:
    cost = 0
    
    income = 0
    
    stocks = pd.read_csv(dir+"\\"+file)
    stocks_close = [float(line) for line in stocks['Close']]
    stocks_volume = [float(line) for line in stocks['Volume']]
    stocks_high = [float(line) for line in stocks['High']]
    stocks_low = [float(line) for line in stocks['Low']]
    stocks.columns = ['date', 'open', 'high', 'low', 'close', 'volume']
    rsiLine = abstract.RSI(stocks, 9)
    detail = [['日期', '買/賣(+/-)', '價格', '價格(稅)', '實際花費', '目前獲利']]
    temp_detail = []
    unit = 1
    stock = 0
    gain = 0
    buy=0
    
    for i in range(1, len(rsiLine)):
        if(((rsiLine[i - 1] > 20 and rsiLine[i] < 20) or (rsiLine[i - 1] < 20 and rsiLine[i] < 20) )and buy==0 and stocks_volume[i]>1000):
            stock += unit
            #計算目前獲利
            gain -= round(unit * stocks_close[i] * 1000 * 1.001425)
            #紀錄交易資訊
            temp_detail.append( '1' )
            temp_detail.append('+' + str(unit))
            temp_detail.append(stocks_close[i])
            temp_detail.append(round(stocks_close[i] * 1.001425, 1))
            temp_detail.append('-' + str(round(unit * stocks_close[i] * 1000 * 1.001425)))
            temp_detail.append(gain)
            detail.append(temp_detail)
            temp_detail = []
            buy=1
        
        if(rsiLine[i - 1] > 80 and rsiLine[i] < 80 and stock > 0):
        
            #計算目前獲利
            gain += round(stock * stocks_close[i] * 1000 * 0.995575)
            #紀錄交易資訊
            temp_detail.append( '2' )
            temp_detail.append('-' + str(stock))
            temp_detail.append(stocks_close[i])
            temp_detail.append(round(stocks_close[i] * 0.995575))
            temp_detail.append('+' + str(round(stock * stocks_close[i] * 1000 * 0.995575)))
            temp_detail.append(gain)
            detail.append(temp_detail)
            #股票全數賣出
            stock = 0
            temp_detail = []
            buy = 0
    if(stock==1):
        gain += round(stock * stocks_close[i] * 1000 * 0.995575)
        temp_detail.append(i)
        temp_detail.append('-' + str(stock))
        temp_detail.append(stocks_close[i])
        temp_detail.append(round(stocks_close[i] * 0.995575))
        temp_detail.append('+' + str(round(stock * stocks_close[i] * 1000 * 0.995575)))
        temp_detail.append(gain)
        detail.append(temp_detail)
        buy = 0
        stock = 0
        temp_detail = []    
    
    for i in range(1, len(detail)):
        #支出總和
        if(float(detail[i][4]) < 0):
            cost += abs(int(detail[i][4]))
        #收入總和
        elif(float(detail[i][4]) > 0):
            income += int(detail[i][4])
    detail = pd.DataFrame(detail)

    print(detail)
    
    #總資訊
    print("支出：", cost, "元")
    print("收入：", income, "元")
    print("淨收益：", income - cost, "元")
    if(cost!=0):
        print("投資報酬率：", round(100 * (income - cost) / cost, 2), "%")
    else:
        print("投資報酬率：0%")
    print('\n')
# Out:
# ['stocks_1101.csv', 'stocks_1312.csv', 'stocks_2327.csv', 'stocks_2330.csv', 'stocks_2412.csv', 'stocks_2881.csv', 'stocks_3008.csv', 'stocks_3046.csv', 'stocks_3105.csv', 'stocks_3227.csv', 'stocks_3406.csv', 'stocks_4968.csv', 'stocks_5469.csv', 'stocks_6452.csv', 'stocks_9958.csv']
#     0         1      2      3       4       5
# 0  日期  買/賣(+/-)     價格  價格(稅)    實際花費    目前獲利
# 1   1        +1  37.25   37.3  -37303  -37303
# 2   2        -1  42.35     42  +42163    4860
# 3   1        +1  38.85   38.9  -38905  -34045
# 4   2        -1  44.95     45  +44751   10706
# 5   1        +1  40.05   40.1  -40107  -29401
# 6   2        -1   42.4     42  +42212   12811
# 支出： 116315 元
# 收入： 129126 元
# 淨收益： 12811 元
# 投資報酬率： 11.01 %
#
#
#     0         1      2      3       4       5
# 0  日期  買/賣(+/-)     價格  價格(稅)    實際花費    目前獲利
# 1   1        +1   21.3   21.3  -21330  -21330
# 2   2        -1  19.05     19  +18966   -2364
# 3   1        +1   16.8   16.8  -16824  -19188
# 4   2        -1  18.35     18  +18269    -919
# 支出： 38154 元
# 收入： 37235 元
# 淨收益： -919 元
# 投資報酬率： -2.41 %
#
#
#     0         1      2      3        4        5
# 0  日期  買/賣(+/-)     價格  價格(稅)     實際花費     目前獲利
# 1   1        +1  280.5  280.9  -280900  -280900
# 2   2        -1  265.5    264  +264325   -16575
# 3   1        +1    320  320.5  -320456  -337031
# 4   2        -1    410    408  +408186    71155
# 5   1        +1    330  330.5  -330470  -259315
# 6   2        -1    423    421  +421128   161813
# 支出： 931826 元
# 收入： 1093639 元
# 淨收益： 161813 元
# 投資報酬率： 17.37 %
#
#
#     0         1      2      3        4        5
# 0  日期  買/賣(+/-)     價格  價格(稅)     實際花費     目前獲利
# 1   1        +1    234  234.3  -234333  -234333
# 2   2        -1  276.5    275  +275276    40943
# 3   1        +1  276.5  276.9  -276894  -235951
# 4   2        -1  320.5    319  +319082    83131
# 支出： 511227 元
# 收入： 594358 元
# 淨收益： 83131 元
# 投資報酬率： 16.26 %
#
#
#     0         1    2      3        4        5
# 0  日期  買/賣(+/-)   價格  價格(稅)     實際花費     目前獲利
# 1   1        +1  107  107.2  -107152  -107152
# 2   2        -1  112    112  +111504     4352
# 支出： 107152 元
# 收入： 111504 元
# 淨收益： 4352 元
# 投資報酬率： 4.06 %
#
#
#     0         1      2      3       4       5
# 0  日期  買/賣(+/-)     價格  價格(稅)    實際花費    目前獲利
# 1   1        +1  43.15   43.2  -43211  -43211
# 2   2        -1   45.2     45  +45000    1789
# 3   1        +1   40.5   40.6  -40558  -38769
# 4   2        -1  45.25     45  +45050    6281
# 支出： 83769 元
# 收入： 90050 元
# 淨收益： 6281 元
# 投資報酬率： 7.5 %
#
#
#      0         1     2       3         4         5
# 0   日期  買/賣(+/-)    價格   價格(稅)      實際花費      目前獲利
# 1    1        +1  3850  3855.5  -3855486  -3855486
# 2  475        -1  3325    3310  +3310287   -545199
# 支出： 3855486 元
# 收入： 3310287 元
# 淨收益： -545199 元
# 投資報酬率： -14.14 %
#
#
#     0         1   2      3     4     5
# 0  日期  買/賣(+/-)  價格  價格(稅)  實際花費  目前獲利
# 支出： 0 元
# 收入： 0 元
# 淨收益： 0 元
# 投資報酬率：0%
#
#
#      0         1      2      3        4        5
# 0   日期  買/賣(+/-)     價格  價格(稅)     實際花費     目前獲利
# 1    1        +1  195.5  195.8  -195779  -195779
# 2  475        -1    346    344  +344469   148690
# 支出： 195779 元
# 收入： 344469 元
# 淨收益： 148690 元
# 投資報酬率： 75.95 %
#
#
#     0         1      2      3        4        5
# 0  日期  買/賣(+/-)     價格  價格(稅)     實際花費     目前獲利
# 1   1        +1  118.5  118.7  -118669  -118669
# 2   2        -1  216.5    216  +215542    96873
# 支出： 118669 元
# 收入： 215542 元
# 淨收益： 96873 元
# 投資報酬率： 81.63 %
#
#
#     0         1      2      3        4        5
# 0  日期  買/賣(+/-)     價格  價格(稅)     實際花費     目前獲利
# 1   1        +1  373.5    374  -374032  -374032
# 2   2        -1    561    559  +558518   184486
# 支出： 374032 元
# 收入： 558518 元
# 淨收益： 184486 元
# 投資報酬率： 49.32 %
#
#
#     0         1      2      3        4        5
# 0  日期  買/賣(+/-)     價格  價格(稅)     實際花費     目前獲利
# 1   1        +1  110.5  110.7  -110657  -110657
# 2   2        -1  179.5    179  +178706    68049
# 支出： 110657 元
# 收入： 178706 元
# 淨收益： 68049 元
# 投資報酬率： 61.5 %
#
#
#     0         1      2      3       4       5
# 0  日期  買/賣(+/-)     價格  價格(稅)    實際花費    目前獲利
# 1   1        +1  37.65   37.7  -37704  -37704
# 2   2        -1   44.1     44  +43905    6201
# 支出： 37704 元
# 收入： 43905 元
# 淨收益： 6201 元
# 投資報酬率： 16.45 %
#
#
#      0         1     2      3        4        5
# 0   日期  買/賣(+/-)    價格  價格(稅)     實際花費     目前獲利
# 1    1        +1   170  170.2  -170242  -170242
# 2  391        -1  56.6     56   +56350  -113892
# 支出： 170242 元
# 收入： 56350 元
# 淨收益： -113892 元
# 投資報酬率： -66.9 %
#
#
#      0         1      2      3        4       5
# 0   日期  買/賣(+/-)     價格  價格(稅)     實際花費    目前獲利
# 1    1        +1     62   62.1   -62088  -62088
# 2    2        -1   76.8     76   +76460   14372
# 3    1        +1  111.5  111.7  -111659  -97287
# 4  475        -1    114    113  +113496   16209
# 支出： 173747 元
# 收入： 189956 元
# 淨收益： 16209 元
# 投資報酬率： 9.33 %

# %%
# !pip install TA_Lib-0.4.19-cp38-cp38-win_amd64.whl
# Out:
# Processing c:\users\oscar\onedrive\桌面\股票分析與程式設計\tactics\ta_lib-0.4.19-cp38-cp38-win_amd64.whl
# Installing collected packages: TA-Lib
# Successfully installed TA-Lib-0.4.19

# %%
# !python -V
# Out:
# Python 3.8.3
