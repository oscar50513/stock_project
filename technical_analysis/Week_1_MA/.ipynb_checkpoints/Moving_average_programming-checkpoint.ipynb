# %%
# !pip install mplfinance
# Out:
# Requirement already satisfied: mplfinance in c:\users\landis\anaconda3\lib\site-packages (0.12.7a17)
# Requirement already satisfied: matplotlib in c:\users\landis\anaconda3\lib\site-packages (from mplfinance) (3.4.3)
# Requirement already satisfied: pandas in c:\users\landis\anaconda3\lib\site-packages (from mplfinance) (1.3.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\landis\anaconda3\lib\site-packages (from matplotlib->mplfinance) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\landis\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\landis\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\landis\anaconda3\lib\site-packages (from matplotlib->mplfinance) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\landis\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\landis\anaconda3\lib\site-packages (from matplotlib->mplfinance) (8.4.0)
# Requirement already satisfied: six in c:\users\landis\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->mplfinance) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\landis\anaconda3\lib\site-packages (from pandas->mplfinance) (2021.3)

# %%
#Part1 介紹的自製移動平均線
import numpy as np
import pandas as pd
import mplfinance as mpf

stocks = pd.read_csv('2330.csv')

stocks = stocks.set_index(pd.DatetimeIndex(stocks["Date"]))
print(stocks.head())
stocks.iloc[:, 0] = pd.to_datetime(stocks.iloc[:, 0], format = "%Y/%m/%d")
print(stocks.head())
stocks = ㄋ.loc['2019/11/05':,:]
print(stocks.head())
colorSet = mpf.make_marketcolors(up = 'r', down = 'g')

styleSet = mpf.make_mpf_style(marketcolors = colorSet)

kwargs = dict(type = 'candle', figscale = 2, style = styleSet)

stocks_close = [line for line in stocks['Close']]

def making_averages(days):
    days_mav = [np.nan] * (days - 1)
    for i in range((days - 1), len(stocks_close)):
        days_mav.append( sum( stocks_close[i-(days - 1) : i+1]) / (days) )
    return days_mav

addplots = [
            mpf.make_addplot(making_averages(5), color = 'black'),
            mpf.make_addplot(making_averages(10), color = 'saddlebrown')
           ]

mpf.plot(stocks, **kwargs, addplot = addplots)
# Out:
#                   Date   Open   High    Low  Close  Volume
# Date
# 2019-01-02  2019/01/02  226.5  226.5  219.0  219.5   32900
# 2019-01-03  2019/01/03  214.0  218.0  214.0  215.5   34616
# 2019-01-04  2019/01/04  211.5  211.5  206.5  208.0   67044
# 2019-01-07  2019/01/07  212.0  214.0  211.0  213.0   35695
# 2019-01-08  2019/01/08  212.0  212.5  210.0  211.0   23794
#                  Date   Open   High    Low  Close  Volume
# Date
# 2019-01-02 2019-01-02  226.5  226.5  219.0  219.5   32900
# 2019-01-03 2019-01-03  214.0  218.0  214.0  215.5   34616
# 2019-01-04 2019-01-04  211.5  211.5  206.5  208.0   67044
# 2019-01-07 2019-01-07  212.0  214.0  211.0  213.0   35695
# 2019-01-08 2019-01-08  212.0  212.5  210.0  211.0   23794
#            Date   Open   High    Low  Close  Volume
# Date
# 2019-01-02  NaT  226.5  226.5  219.0  219.5   32900
# 2019-01-03  NaT  214.0  218.0  214.0  215.5   34616
# 2019-01-04  NaT  211.5  211.5  206.5  208.0   67044
# 2019-01-07  NaT  212.0  214.0  211.0  213.0   35695
# 2019-01-08  NaT  212.0  212.5  210.0  211.0   23794
# C:\Users\Landis\anaconda3\lib\site-packages\mplfinance\_arg_validators.py:35: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+
