# %%
# 王嬿甯 
# 未完成加分題
import mplfinance as mpf
import pandas as pd
import matplotlib.pyplot as plt

SData = pd.read_csv('2377.csv',index_col = 'Date')
SData.index = pd.DatetimeIndex(SData.index)
SData = SData.loc['2021/08/01':,:]
mc = mpf.make_marketcolors(up='r',down='g',volume='inherit',edge='inherit')
cs = mpf.make_mpf_style(marketcolors=mc,gridcolor='lightgray')

mpf.plot(SData,type='candle',title='2377',ylabel='price',
         ylabel_lower='Volume', 
         volume=True,
         mav=(5,20,60),style=cs)

# %%
# 熊亭媛
from datetime import datetime
import pandas as pd
import time
import mplfinance as mpf

SData = pd.read_csv('2377.csv', index_col = 'Date')
SData.index = pd.DatetimeIndex(SData.index)
SData = SData.tail(72)

high = 0
low = 200

for i in SData['High']:
    if i  > high:
        high = i
print(high)
for i in SData['Low']:
    if i  < low:
        low = i
print(low)


mc = mpf.make_marketcolors(up ='r',down = 'g', volume = 'inherit',edge = 'inherit')
cs = mpf.make_mpf_style(marketcolors =mc, gridcolor ="lightgray")
mpf.plot(SData,type= "candle", volume =True, style =cs,mav = [5,20,60])
# Out:
# 173.0
# 117.0

# %%
#  李郁青
# 未完成加分題
from datetime import datetime
import pandas as pd
import time
import mplfinance as mpf

sdata = pd.read_csv('2377.csv', index_col = 'Date')
sdata.index = pd.DatetimeIndex(sdata.index)
sdata = sdata.loc['2021/08/01':,:]
mc = mpf.make_marketcolors(up='r', down='g', volume='inherit', edge='inherit')
cs = mpf.make_mpf_style(marketcolors=mc, gridcolor='lightgray')
mpf.plot(sdata, type='candle',ylabel='Price',ylabel_lower='Volume', volume=True,mav=(5, 20, 60),style=cs)

# %%
# Joseph Wang
# 未完成加分題
import mplfinance as mpf
import pandas as pd
SData = pd.read_csv('2377.csv',index_col = 'Date')
SData.index = pd.DatetimeIndex(SData.index)
SData = SData.loc['2021/8/02':,:]
mc = mpf.make_marketcolors(up ='r',down='g',volume='inherit',edge='inherit')
cs = mpf.make_mpf_style(marketcolors = mc, gridcolor = 'lightgray')
mpf.plot(SData,type='candle',title = '',ylabel = 'Price',ylabel_lower = 'Volume',volume=True,style = cs,mav=(5,20,60))

# %%
# 陳冠勳 
# 未完成加分題
import mplfinance as mpf
import pandas as pd

#import file
SData = pd.read_csv('2377.csv', index_col = 'Date')
#end import

SData.index = pd.DatetimeIndex(SData.index)
SData = SData.tail(72)

mc = mpf.make_marketcolors(up = 'r', down = 'g', volume = 'inherit', edge = 'inherit')
cs = mpf.make_mpf_style(marketcolors = mc, gridcolor = "lightgray")

mpf.plot(SData, type = 'candle', volume = True, style = cs, mav = (5, 20, 60))

# %%
# 楊秉樺
import mplfinance as mpf
import pandas as pd
sdata = pd.read_csv('2377.csv', index_col='Date')
sdata.index = pd.DatetimeIndex(sdata.index)
sdata = sdata.loc['2021/08/01':, :]
mc = mpf.make_marketcolors(up = 'r', down = 'g', volume = 'inherit', edge = 'inherit')
cs = mpf.make_mpf_style(marketcolors=mc,gridcolor='lightgray')
mpf.plot(sdata, type='candle', volume=True, ylabel='Price', ylabel_lower='Volume', style=cs, mav=(5, 20, 60))
s_close = [line for line in sdata['Close']]
high = max(s_close)
low = min(s_close)
print('最高價為: ' + str(high) + '\n最低價為: ' + str(low))
# Out:
# 最高價為: 166.5
# 最低價為: 119.5

# %%
# 馮綺華 
# 日期選取出錯
# 未完成加分題
import mplfinance as mpf
import pandas as pd
from datetime import datetime
import time
import mplfinance as mpf
SData = pd.read_csv('2377.csv', index_col = 'Date')
SData.index = pd.DatetimeIndex(SData.index)
#SData1 = SData.loc['2021/08/02':,:]
SData1 = SData.loc['2021/8/2':,:]
SData1 = [line.strftime("%m/%d") for line in SData.index]

SData1 = SData.tail(100)
mc = mpf.make_marketcolors(up='r', down='g', volume='inherit', edge='inherit')
cs = mpf.make_mpf_style(marketcolors=mc, gridcolor="lightgray")
mpf.plot(SData1, type='candle', ylabel= 'Price', ylabel_lower = 'Volume', volume=True, mav = (5,20,60),style = cs)

# %%
# 410721202 
import mplfinance as mpf
import pandas as pd

data = pd.read_csv('2377.csv', index_col = 'Date')
data = data[383:]
maxp = float(data['High'][0])
minp = float(data['Low'][0])
for i in data['High']:
    if i > maxp:
        maxp = i
for i in data['Low']:
    if i < minp:
        minp = i
print('最高價為: ', maxp, '\n最低價為: ', minp)

data.index = pd.DatetimeIndex(data.index)
mc = mpf.make_marketcolors(up='r', down='g', edge='inherit', volume='inherit', wick='black')
cs = mpf.make_mpf_style(marketcolors=mc, gridcolor='lightgray')
mpf.plot(data, type='candle', title='2377_2021_08', ylabel='Price', ylabel_lower='Volume', volume=True, style=cs, mav=[5,20,60])
# Out:
# 最高價為:  173.0
# 最低價為:  117.0

# %%
# 林卉蓁
# 日期選取出錯
import mplfinance as mpf
import pandas as pd
data=pd.read_csv('2377.csv',index_col='Date')
data=data.iloc[139:]
data.index=pd.DatetimeIndex(data.index)
max=data['High'].max()
min=data['Low'].min()
print('最高價為:',max)
print('最低價為:',min)
mc=mpf.make_marketcolors(up='r',down='g',volume='inherit',edge='inherit',wick={'up':'r','down':'g'})
cs=mpf.make_mpf_style(marketcolors=mc,gridcolor='#d3bfb7')
mpf.plot(data,type='candle',ylabel='Price',ylabel_lower='Volume',volume=True,mav=(5,20,60),style=cs)
# Out:
# 最高價為: 203.0
# 最低價為: 112.5

# %%
# 劉沛妮
import mplfinance as mpf
import pandas as pd
SData = pd.read_csv('2377.csv',index_col='Date')
SData.index = pd.DatetimeIndex(SData.index)
SData = SData.loc['2021/08':,:]
max = 0
for i in SData["High"]:
    if i >= max:
        max = i
min = 999999
for i in SData["Low"]:
    if i <= min:
        min = i
print("最高價為: ",max)
print("最低價為: ",min)
mc = mpf.make_marketcolors(up='r', down='g', volume='inherit', edge='inherit')
cs = mpf.make_mpf_style(marketcolors=mc, gridcolor= 'lightgray')
mpf.plot(SData,type='candle',
         volume=True,
         style=cs,
         mav=(5, 20, 60))
# Out:
# 最高價為:  173.0
# 最低價為:  117.0

# %%
# 周宗翔
# 未畫出移動平均線
from datetime import datetime
import pandas as pd
import time
import mplfinance as mpf
Sdata = pd.read_csv('2377.csv',index_col='Date')
Sdata = Sdata.tail(72)
Sdata.index=pd.DatetimeIndex(Sdata.index)
mc = mpf.make_marketcolors(up='r',down='g',volume='inherit',edge='inherit')
cs = mpf.make_mpf_style(marketcolors=mc,gridcolor='lightgray')
tempData = open('2377.csv').readlines()
tempData1 = [line.strip('n').split(',')for line in tempData[385:] ]
high = []
low = []
cur = 0
for line in tempData1:
    high.append(float(tempData1[cur][2]))
    low.append(float(tempData1[cur][3]))
    cur+=1
#print("最高價:", max(high))
#print("最低價:", min(low))
mpf.plot(Sdata,type='candle',volume=True,style=cs)

# %%
# 楊右宇
import pandas as pd
import mplfinance as mpf
df = pd.read_csv("2377.csv", index_col = 0, parse_dates=True)
df = df.loc["2021-08":]
print("最高價為 :", df["High"].max())
print("最低價為 :", df["Low"].min())

my_color = mpf.make_marketcolors(up="red", down="green", edge="i", volume="in", inherit=False)
my_style = mpf.make_mpf_style(gridaxis="both", gridstyle="-", marketcolors=my_color, gridcolor="lightgray")

mpf.plot(df, type="candle", mav=(5, 20, 60), volume=True, style=my_style, ylabel="Price", ylabel_lower="Volume")
# Out:
# 最高價為 : 173.0
# 最低價為 : 117.0

# %%
# 呂皇逸 
import mplfinance as mpf
import pandas as pd
import numpy as np
datas = pd.read_csv("2377.csv",index_col="Date")
datas.index = pd.DatetimeIndex(datas.index)
datas=datas.loc['2021/08/01':,:]
Highest = 0
for lines in datas['High']:
    if(Highest < np.float(lines)):
        Highest = lines
Lowest = 999
for lines in datas['Low']:
    if(Lowest > np.float(lines)):
        Lowest = lines
print("最高價為:",Highest)
print("最低價為:",Lowest)
mc = mpf.make_marketcolors(up='r',down='g',volume='inherit',edge='inherit')
cs = mpf.make_mpf_style(marketcolors=mc,gridcolor='lightgray')
mpf.plot(datas,type='candle',
        title='2377',
        ylabel='Price',
        ylabel_lower='Volume',
        volume=True,
        mav=(5,20,60),
        style=cs)
# Out:
# C:\Users\Landis\AppData\Local\Temp/ipykernel_20252/3985256662.py:9: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if(Highest < np.float(lines)):
# C:\Users\Landis\AppData\Local\Temp/ipykernel_20252/3985256662.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if(Lowest > np.float(lines)):
# 最高價為: 173.0
# 最低價為: 117.0

# %%
# 410921229 
import pandas as pd
import mplfinance as mpf

Data = pd.read_csv('2377.csv',index_col='Date')
Data.index = pd.DatetimeIndex(Data.index)

Data=Data.loc['2021/08':]

mc = mpf.make_marketcolors(up='r',down='g',volume='inherit',edge='inherit')
cs = mpf.make_mpf_style(marketcolors=mc,gridcolor='lightgray')

print('最高價為'+str(Data['High'].max()))
print('最低價為'+str(Data['Low'].min()))
mpf.plot(Data,type='candle',mav=(5,20,60),style=cs,volume=True,title='n2377')
# Out:
# 最高價為173.0
# 最低價為117.0

# %%
# 謝旻倫 
# 未完成加分題
import mplfinance as mpf
import pandas as pd 
Sdata = pd.read_csv('2377.csv' , index_col =  "Date")
Sdata.index = pd.DatetimeIndex(Sdata.index)
Sdata = Sdata.loc['2021/08/01':,:]
mc = mpf.make_marketcolors(up = 'r' , down = 'g' , volume = 'inherit' , edge = 'inherit')
cs = mpf.make_mpf_style(marketcolors = mc , gridcolor = 'lightgray')
mpf.plot(Sdata, type = 'candle' , ylabel = "price", ylabel_lower = "volume" ,volume = True , style = cs , mav = (5,20,60))

# %%
# 廖廣筑 
from datetime import datetime
import pandas as pd
import mplfinance as mpf
SData = pd.read_csv('2377.csv',index_col = 'Date')
SData.index = pd.DatetimeIndex(SData.index)
SData = SData.tail(70)
cl=['Date','Open','High','Low','Close','Volume']
df1= pd.DataFrame(SData,columns=cl) 
max_df1 = df1['High'].max()
print('最高價:',round(max_df1,2))
df1= pd.DataFrame(SData,columns=cl) 
min_df1 = df1['Low'].min()
print('最低價:',round(min_df1,2))

mc = mpf.make_marketcolors(up = 'r' , down="g",volume='inherit',edge='inherit')
cs = mpf.make_mpf_style(marketcolors = mc , gridcolor = "lightgray")

mpf.plot(SData,type = 'candle',
         ylabel='price',
         ylabel_lower='Volume',
         volume= True,
         style = cs,
         mav = (5,20,60))
# Out:
# 最高價: 173.0
# 最低價: 117.0

# %%
# 吳晨瑄 
from datetime import datetime
import pandas as pd
import time
import mplfinance as mpf
SData = pd.read_csv('2377.csv',index_col='Date')
SData.index = pd.DatetimeIndex(SData.index)

SData = SData.loc['2021/08': , : ]

#print("最高價為:",max(SData.High))
#print("最低價為:",min(SData.Low))

mc = mpf.make_marketcolors(up = 'r',down = 'g',volume='inherit',edge = 'inherit')
cs = mpf.make_mpf_style(marketcolors = mc, gridcolor = "lightgray")
mpf.plot(SData,type = 'candle', mav = [5,20,60], volume = True,style = cs)

# %%
# 410921233
import mplfinance as mpf
import pandas as pd
Sdata=pd.read_csv('2377.csv',index_col='Date')
Sdata = Sdata.loc['2021/08':,:]
Sdata.index = pd.DatetimeIndex(Sdata.index)
mc =mpf.make_marketcolors(up='g',down='r',volume='inherit',edge = 'inherit')
cs =mpf.make_mpf_style(marketcolors=mc,gridcolor='lightgray')
print( "最高價:" ,Sdata['High'].max())
print("最低價:" ,Sdata['Low'].min())
mpf.plot(Sdata,
        type='candle',
        volume=True,
         style =cs,
        mav=(5,20,60),
        datetime_format='%b %d')
# Out:
# 最高價: 173.0
# 最低價: 117.0
